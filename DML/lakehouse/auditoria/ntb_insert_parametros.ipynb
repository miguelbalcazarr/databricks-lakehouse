-- %%
INSERT INTO lakehouse.auditoria.parametros
  VALUES
    (
      "sales",
      "SELECT [CountryRegionCode]
      ,[CurrencyCode]
      ,[ModifiedDate]
  FROM [Sales].[CountryRegionCurrency]",
      "sales_countryregioncurrency",
      "bronze.sales_countryregioncurrency",
      "1"
    ),
    (
      "sales",
      "SELECT [CreditCardID]
      ,[CardType]
      ,[CardNumber]
      ,[ExpMonth]
      ,[ExpYear]
      ,[ModifiedDate]
  FROM [Sales].[CreditCard]",
      "sales_creditcard",
      "bronze.sales_creditcard",
      "1"
    ),
    (
      "sales",
      "SELECT [CurrencyCode]
      ,[Name]
      ,[ModifiedDate]
  FROM [Sales].[Currency]",
      "sales_currency",
      "bronze.sales_currency",
      "1"
    ),
    (
      "sales",
      "SELECT [CurrencyRateID]
      ,[CurrencyRateDate]
      ,[FromCurrencyCode]
      ,[ToCurrencyCode]
      ,[AverageRate]
      ,[EndOfDayRate]
      ,[ModifiedDate]
  FROM [Sales].[CurrencyRate]",
      "sales_currencyrate",
      "bronze.sales_currencyrate",
      "1"
    ),
    (
      "sales",
      "SELECT [CustomerID]
      ,[PersonID]
      ,[StoreID]
      ,[TerritoryID]
      ,[AccountNumber]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[Customer]",
      "sales_customer",
      "bronze.sales_customer",
      "1"
    ),
    (
      "sales",
      "SELECT [BusinessEntityID]
      ,[CreditCardID]
      ,[ModifiedDate]
  FROM [Sales].[PersonCreditCard]",
      "sales_personcreditcard",
      "bronze.sales_personcreditcard",
      "1"
    ),
    (
      "sales",
      "SELECT [SalesOrderID]
      ,[SalesOrderDetailID]
      ,[CarrierTrackingNumber]
      ,[OrderQty]
      ,[ProductID]
      ,[SpecialOfferID]
      ,[UnitPrice]
      ,[UnitPriceDiscount]
      ,[LineTotal]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesOrderDetail]",
      "sales_salesorderdetail",
      "bronze.sales_salesorderdetail",
      "1"
    ),
    (
      "sales",
      "SELECT [SalesOrderID]
      ,[RevisionNumber]
      ,[OrderDate]
      ,[DueDate]
      ,[ShipDate]
      ,[Status]
      ,[OnlineOrderFlag]
      ,[SalesOrderNumber]
      ,[PurchaseOrderNumber]
      ,[AccountNumber]
      ,[CustomerID]
      ,[SalesPersonID]
      ,[TerritoryID]
      ,[BillToAddressID]
      ,[ShipToAddressID]
      ,[ShipMethodID]
      ,[CreditCardID]
      ,[CreditCardApprovalCode]
      ,[CurrencyRateID]
      ,[SubTotal]
      ,[TaxAmt]
      ,[Freight]
      ,[TotalDue]
      ,[Comment]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesOrderHeader]",
      "sales_salesorderheader",
      "bronze.sales_salesorderheader",
      "1"
    ),
    (
      "sales",
      "SELECT [SalesOrderID]
      ,[SalesReasonID]
      ,[ModifiedDate]
  FROM [Sales].[SalesOrderHeaderSalesReason]",
      "sales_salesorderheadersalesreason",
      "bronze.sales_salesorderheadersalesreason",
      "1"
    ),
    (
      "sales",
      "SELECT [BusinessEntityID]
      ,[TerritoryID]
      ,[SalesQuota]
      ,[Bonus]
      ,[CommissionPct]
      ,[SalesYTD]
      ,[SalesLastYear]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesPerson]",
      "sales_salesperson",
      "bronze.sales_salesperson",
      "1"
    ),
    (
      "sales",
      "SELECT [BusinessEntityID]
      ,[QuotaDate]
      ,[SalesQuota]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesPersonQuotaHistory]",
      "sales_salespersonquotahistory",
      "bronze.sales_salespersonquotahistory",
      "1"
    ),
    (
      "sales",
      "SELECT [SalesReasonID]
      ,[Name]
      ,[ReasonType]
      ,[ModifiedDate]
  FROM [Sales].[SalesReason]",
      "sales_salesreason",
      "bronze.sales_salesreason",
      "1"
    ),
    (
      "sales",
      "SELECT [SalesTaxRateID]
      ,[StateProvinceID]
      ,[TaxType]
      ,[TaxRate]
      ,[Name]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesTaxRate]",
      "sales_salestaxrate",
      "bronze.sales_salestaxrate",
      "1"
    ),
    (
      "sales",
      "SELECT [TerritoryID]
      ,[Name]
      ,[CountryRegionCode]
      ,[Group]
      ,[SalesYTD]
      ,[SalesLastYear]
      ,[CostYTD]
      ,[CostLastYear]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesTerritory]",
      "sales_salesterritory",
      "bronze.sales_salesterritory",
      "1"
    ),
    (
      "sales",
      "SELECT [BusinessEntityID]
      ,[TerritoryID]
      ,[StartDate]
      ,[EndDate]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SalesTerritoryHistory]",
      "sales_salesterritoryhistory",
      "bronze.sales_salesterritoryhistory",
      "1"
    ),
    (
      "sales",
      "SELECT [ShoppingCartItemID]
      ,[ShoppingCartID]
      ,[Quantity]
      ,[ProductID]
      ,[DateCreated]
      ,[ModifiedDate]
  FROM [Sales].[ShoppingCartItem]",
      "sales_shoppingcartitem",
      "bronze.sales_shoppingcartitem",
      "1"
    ),
    (
      "sales",
      "SELECT [SpecialOfferID]
      ,[Description]
      ,[DiscountPct]
      ,[Type]
      ,[Category]
      ,[StartDate]
      ,[EndDate]
      ,[MinQty]
      ,[MaxQty]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SpecialOffer]",
      "sales_specialoffer",
      "bronze.sales_specialoffer",
      "1"
    ),
    (
      "sales",
      "SELECT [SpecialOfferID]
      ,[ProductID]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[SpecialOfferProduct]",
      "sales_specialofferproduct",
      "bronze.sales_specialofferproduct",
      "1"
    ),
    (
      "sales",
      "SELECT [BusinessEntityID]
      ,[Name]
      ,[SalesPersonID]
      ,[Demographics]
      ,[rowguid]
      ,[ModifiedDate]
  FROM [Sales].[Store]",
      "sales_store",
      "bronze.sales_store",
      "1"
    )

-- %%
select * from lakehouse.auditoria.parametros
